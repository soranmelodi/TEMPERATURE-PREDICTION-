# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('weather_data.csv')
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
# 2                     204          14.9569           0               1015.94
# 3                     269          15.8263           0               1016.41
# 4                     259          15.8263           0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   object
#  1   Summary                   5999 non-null   object
#  2   Precip Type               5999 non-null   object
#  3   Temperature (C)           5999 non-null   float64
#  4   Apparent Temperature (C)  5999 non-null   float64
#  5   Humidity                  5999 non-null   float64
#  6   Wind Speed (km/h)         5999 non-null   float64
#  7   Wind Bearing (degrees)    5999 non-null   int64
#  8   Visibility (km)           5999 non-null   float64
#  9   Loud Cover                5999 non-null   int64
#  10  Pressure (millibars)      5999 non-null   float64
#  11  Daily Summary             5999 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
data.shape
# Out:
# (5999, 12)

# %%
data.size
# Out:
# 71988

# %%
list(data.columns)
# Out:
# ['Formatted Date',
#  'Summary',
#  'Precip Type',
#  'Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Loud Cover',
#  'Pressure (millibars)',
#  'Daily Summary']

# %%
data.describe(include='all')
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                            5999           5999        5999
# unique                           5999             14           2
# top     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                1           1791        4762
# mean                              NaN            NaN         NaN
# std                               NaN            NaN         NaN
# min                               NaN            NaN         NaN
# 25%                               NaN            NaN         NaN
# 50%                               NaN            NaN         NaN
# 75%                               NaN            NaN         NaN
# max                               NaN            NaN         NaN
#
#         Temperature (C)  Apparent Temperature (C)     Humidity  \
# count       5999.000000               5999.000000  5999.000000
# unique              NaN                       NaN          NaN
# top                 NaN                       NaN          NaN
# freq                NaN                       NaN          NaN
# mean          10.217695                  8.958658     0.779488
# std           10.565425                 11.923712     0.173051
# min          -14.088889                -22.094444     0.270000
# 25%            1.094444                 -1.538889     0.680000
# 50%           10.050000                 10.050000     0.830000
# 75%           18.722222                 18.722222     0.920000
# max           34.005556                 36.400000     1.000000
#
#         Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count         5999.000000             5999.000000      5999.000000
# unique                NaN                     NaN              NaN
# top                   NaN                     NaN              NaN
# freq                  NaN                     NaN              NaN
# mean            10.007362              190.349558         9.476875
# std              6.536619              107.026792         4.038583
# min              0.000000                0.000000         0.000000
# 25%              4.878300              122.000000         6.906900
# 50%              9.064300              190.000000         9.982000
# 75%             13.395200              287.000000        11.270000
# max             45.933300              359.000000        16.100000
#
#         Loud Cover  Pressure (millibars)                      Daily Summary
# count       5999.0           5999.000000                               5999
# unique         NaN                   NaN                                 58
# top            NaN                   NaN  Mostly cloudy throughout the day.
# freq           NaN                   NaN                                600
# mean           0.0            997.359828                                NaN
# std            0.0            145.173638                                NaN
# min            0.0              0.000000                                NaN
# 25%            0.0           1012.060000                                NaN
# 50%            0.0           1016.840000                                NaN
# 75%            0.0           1022.490000                                NaN
# max            0.0           1045.140000                                NaN

# %% [markdown]
# ## DATA CLEANING

# %%
# information of data before cleaning.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   object
#  1   Summary                   5999 non-null   object
#  2   Precip Type               5999 non-null   object
#  3   Temperature (C)           5999 non-null   float64
#  4   Apparent Temperature (C)  5999 non-null   float64
#  5   Humidity                  5999 non-null   float64
#  6   Wind Speed (km/h)         5999 non-null   float64
#  7   Wind Bearing (degrees)    5999 non-null   int64
#  8   Visibility (km)           5999 non-null   float64
#  9   Loud Cover                5999 non-null   int64
#  10  Pressure (millibars)      5999 non-null   float64
#  11  Daily Summary             5999 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
cols = ['Summary','Precip Type','Daily Summary','Wind Bearing (degrees)','Visibility (km)','Loud Cover']
data = data.drop(cols,axis=1)

# %%
# Converting Formatted Date from Object to DateTimeObject.
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   object
#  1   Temperature (C)           5999 non-null   float64
#  2   Apparent Temperature (C)  5999 non-null   float64
#  3   Humidity                  5999 non-null   float64
#  4   Wind Speed (km/h)         5999 non-null   float64
#  5   Pressure (millibars)      5999 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 281.3+ KB
# F:\temp\ipykernel_21364\1568472464.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data['Formatted Date'] = pd.to_datetime(data['Formatted Date'])

# %%
# Indexing according to date and time.
idata = data.sort_values(by=['Formatted Date'])

# %%
# Setting Index
idata = idata.set_index('Formatted Date')
idata.index
# Out:
# Index([2006-01-01 00:00:00+01:00, 2006-01-01 01:00:00+01:00,
#        2006-01-01 02:00:00+01:00, 2006-01-01 03:00:00+01:00,
#        2006-01-01 04:00:00+01:00, 2006-01-01 05:00:00+01:00,
#        2006-01-01 06:00:00+01:00, 2006-01-01 07:00:00+01:00,
#        2006-01-01 08:00:00+01:00, 2006-01-01 09:00:00+01:00,
#        ...
#        2006-12-31 14:00:00+01:00, 2006-12-31 15:00:00+01:00,
#        2006-12-31 16:00:00+01:00, 2006-12-31 17:00:00+01:00,
#        2006-12-31 18:00:00+01:00, 2006-12-31 19:00:00+01:00,
#        2006-12-31 20:00:00+01:00, 2006-12-31 21:00:00+01:00,
#        2006-12-31 22:00:00+01:00, 2006-12-31 23:00:00+01:00],
#       dtype='object', name='Formatted Date', length=5999)

# %%
#removing duplicate values in the index
idata.index.drop_duplicates(keep='first')
# Out:
# Index([2006-01-01 00:00:00+01:00, 2006-01-01 01:00:00+01:00,
#        2006-01-01 02:00:00+01:00, 2006-01-01 03:00:00+01:00,
#        2006-01-01 04:00:00+01:00, 2006-01-01 05:00:00+01:00,
#        2006-01-01 06:00:00+01:00, 2006-01-01 07:00:00+01:00,
#        2006-01-01 08:00:00+01:00, 2006-01-01 09:00:00+01:00,
#        ...
#        2006-12-31 14:00:00+01:00, 2006-12-31 15:00:00+01:00,
#        2006-12-31 16:00:00+01:00, 2006-12-31 17:00:00+01:00,
#        2006-12-31 18:00:00+01:00, 2006-12-31 19:00:00+01:00,
#        2006-12-31 20:00:00+01:00, 2006-12-31 21:00:00+01:00,
#        2006-12-31 22:00:00+01:00, 2006-12-31 23:00:00+01:00],
#       dtype='object', name='Formatted Date', length=5999)

# %%
# data after cleaning
idata.dropna()
idata.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+01:00         0.577778                 -4.050000
# 2006-01-01 01:00:00+01:00         1.161111                 -3.238889
# 2006-01-01 02:00:00+01:00         1.666667                 -3.155556
# 2006-01-01 03:00:00+01:00         1.711111                 -2.194444
# 2006-01-01 04:00:00+01:00         1.183333                 -2.744444
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-01-01 00:00:00+01:00      0.89            17.1143               1016.66
# 2006-01-01 01:00:00+01:00      0.85            16.6152               1016.15
# 2006-01-01 02:00:00+01:00      0.82            20.2538               1015.87
# 2006-01-01 03:00:00+01:00      0.82            14.4900               1015.56
# 2006-01-01 04:00:00+01:00      0.86            13.9426               1014.98

# %%
# information of data after after cleaning.
idata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5999 entries, 2006-01-01 00:00:00+01:00 to 2006-12-31 23:00:00+01:00
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (C)           5999 non-null   float64
#  1   Apparent Temperature (C)  5999 non-null   float64
#  2   Humidity                  5999 non-null   float64
#  3   Wind Speed (km/h)         5999 non-null   float64
#  4   Pressure (millibars)      5999 non-null   float64
# dtypes: float64(5)
# memory usage: 410.2+ KB

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
#plotting the data
idata.plot(y="Temperature (C)",figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
#resampling the data into day format
idata.index = pd.to_datetime(idata.index,utc=True)
idata2 = idata.resample(rule='D').mean()
idata2.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00         0.577778                 -4.050000
# 2006-01-01 00:00:00+00:00         4.075000                 -0.174537
# 2006-01-02 00:00:00+00:00         5.263194                  1.808796
# 2006-01-03 00:00:00+00:00         2.340509                  0.445370
# 2006-01-04 00:00:00+00:00         2.251852                 -0.663194
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2005-12-31 00:00:00+00:00  0.890000          17.114300           1016.660000
# 2006-01-01 00:00:00+00:00  0.817083          21.229192           1011.985000
# 2006-01-02 00:00:00+00:00  0.847083          17.824713           1010.384167
# 2006-01-03 00:00:00+00:00  0.897083           7.726658           1021.170833
# 2006-01-04 00:00:00+00:00  0.906667          12.152817            981.770833

# %%
idata2.plot(y="Temperature (C)",figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
#extracting data from the month of January
jan2006 = idata['2006-01-01':'2006-01-31']
jan2006
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+00:00         1.161111                 -3.238889
# 2006-01-01 01:00:00+00:00         1.666667                 -3.155556
# 2006-01-01 02:00:00+00:00         1.711111                 -2.194444
# 2006-01-01 03:00:00+00:00         1.183333                 -2.744444
# 2006-01-01 04:00:00+00:00         1.205556                 -3.072222
# ...                                    ...                       ...
# 2006-01-31 19:00:00+00:00        -2.400000                 -2.400000
# 2006-01-31 20:00:00+00:00        -1.933333                 -1.933333
# 2006-01-31 21:00:00+00:00        -1.922222                 -3.988889
# 2006-01-31 22:00:00+00:00        -2.077778                 -4.455556
# 2006-01-31 23:00:00+00:00        -2.144444                 -6.200000
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-01-01 00:00:00+00:00      0.85            16.6152               1016.15
# 2006-01-01 01:00:00+00:00      0.82            20.2538               1015.87
# 2006-01-01 02:00:00+00:00      0.82            14.4900               1015.56
# 2006-01-01 03:00:00+00:00      0.86            13.9426               1014.98
# 2006-01-01 04:00:00+00:00      0.85            15.9068               1014.08
# ...                             ...                ...                   ...
# 2006-01-31 19:00:00+00:00      0.88             4.6046               1024.54
# 2006-01-31 20:00:00+00:00      0.85             3.2200               1024.29
# 2006-01-31 21:00:00+00:00      0.86             5.4901               1024.66
# 2006-01-31 22:00:00+00:00      0.82             6.1502               1024.87
# 2006-01-31 23:00:00+00:00      0.86            11.2700               1025.18
#
# [744 rows x 5 columns]

# %%
jan2006.plot(y=['Apparent Temperature (C)','Temperature (C)'],kind='line',figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
#resampling
JAN = jan2006.resample(rule='D').mean()
JAN.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+00:00         4.075000                 -0.174537
# 2006-01-02 00:00:00+00:00         5.263194                  1.808796
# 2006-01-03 00:00:00+00:00         2.340509                  0.445370
# 2006-01-04 00:00:00+00:00         2.251852                 -0.663194
# 2006-01-05 00:00:00+00:00         2.703935                  0.445833
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-01-01 00:00:00+00:00  0.817083          21.229192           1011.985000
# 2006-01-02 00:00:00+00:00  0.847083          17.824713           1010.384167
# 2006-01-03 00:00:00+00:00  0.897083           7.726658           1021.170833
# 2006-01-04 00:00:00+00:00  0.906667          12.152817            981.770833
# 2006-01-05 00:00:00+00:00  0.951250           8.991179            935.873750

# %%
JAN.plot(y=['Apparent Temperature (C)','Temperature (C)'],kind='line',figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
winter = idata2['2006-01-01':'2006-02-28']
winter2 = idata2['2006-12-01':'2006-12-31']
spring = idata2['2006-03-01':'2006-05-31']
summer = idata2['2006-06-01':'2006-08-31']

# %%
winter.plot(y= ['Temperature (C)','Apparent Temperature (C)'],figsize=(20,10))
winter2.plot(y= ['Temperature (C)','Apparent Temperature (C)'],figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
spring.plot(y= ['Temperature (C)','Apparent Temperature (C)'],figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %%
summer.plot(y= ['Temperature (C)','Apparent Temperature (C)'],figsize=(20,10))
# Out:
# <Axes: xlabel='Formatted Date'>

# %% [markdown]
# ## Correlation in data

# %%
#checking correlation between the cols

data=idata

data.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992881 -0.564260
# Apparent Temperature (C)         0.992881                  1.000000 -0.535399
# Humidity                        -0.564260                 -0.535399  1.000000
# Wind Speed (km/h)               -0.053935                 -0.126701 -0.209529
# Pressure (millibars)            -0.080315                 -0.077491  0.061836
#
#                           Wind Speed (km/h)  Pressure (millibars)
# Temperature (C)                   -0.053935             -0.080315
# Apparent Temperature (C)          -0.126701             -0.077491
# Humidity                          -0.209529              0.061836
# Wind Speed (km/h)                  1.000000             -0.043172
# Pressure (millibars)              -0.043172              1.000000

# %%
#plotting the correlation
plt.figure(figsize  =(8,8))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
sns.jointplot(x="Temperature (C)", y="Apparent Temperature (C)", kind="reg", data=data)
plt.show()
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(kind='reg',y=data['Humidity'],x=data['Temperature (C)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(kind='reg',y=data['Pressure (millibars)'],x=data['Temperature (C)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot('Apparent Temperature (C)','Pressure (millibars)',kind="reg", data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.jointplot('Apparent Temperature (C)','Pressure (millibars)',kind="reg", data=data)
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
sns.jointplot(kind='reg',y=data['Wind Speed (km/h)'],x=data['Temperature (C)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot('Apparent Temperature (C)','Wind Speed (km/h)',kind="reg", data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sns.jointplot('Apparent Temperature (C)','Wind Speed (km/h)',kind="reg", data=data)
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
sns.jointplot('Apparent Temperature (C)','Humidity',kind="reg", data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.jointplot('Apparent Temperature (C)','Humidity',kind="reg", data=data)
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
sns.jointplot(kind='hex',y=data['Humidity'],x=data['Pressure (millibars)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(kind='hex',y=data['Humidity'],x=data['Temperature (C)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(kind='hex',y=data['Humidity'],x=data['Apparent Temperature (C)'])
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize =(20,20))
sns.pairplot(data)
plt.show()
# Out:
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\a\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#taking 70% of the data for training
X = idata['2006-01-01':'2006-07-20']
X
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+00:00         1.161111                 -3.238889
# 2006-01-01 01:00:00+00:00         1.666667                 -3.155556
# 2006-01-01 02:00:00+00:00         1.711111                 -2.194444
# 2006-01-01 03:00:00+00:00         1.183333                 -2.744444
# 2006-01-01 04:00:00+00:00         1.205556                 -3.072222
# ...                                    ...                       ...
# 2006-07-20 19:00:00+00:00        25.027778                 25.027778
# 2006-07-20 20:00:00+00:00        23.244444                 23.244444
# 2006-07-20 21:00:00+00:00        22.255556                 22.255556
# 2006-07-20 22:00:00+00:00        19.494444                 19.494444
# 2006-07-20 23:00:00+00:00        19.422222                 19.422222
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-01-01 00:00:00+00:00      0.85            16.6152               1016.15
# 2006-01-01 01:00:00+00:00      0.82            20.2538               1015.87
# 2006-01-01 02:00:00+00:00      0.82            14.4900               1015.56
# 2006-01-01 03:00:00+00:00      0.86            13.9426               1014.98
# 2006-01-01 04:00:00+00:00      0.85            15.9068               1014.08
# ...                             ...                ...                   ...
# 2006-07-20 19:00:00+00:00      0.62             0.0000               1020.38
# 2006-07-20 20:00:00+00:00      0.70             1.1109               1020.61
# 2006-07-20 21:00:00+00:00      0.79             2.7370               1020.75
# 2006-07-20 22:00:00+00:00      0.84             1.6100               1020.80
# 2006-07-20 23:00:00+00:00      0.90             3.1234               1020.71
#
# [4248 rows x 5 columns]

# %%
#30% of data for testing
X1 = idata['2006-07-21':'2006-12-31']
X1
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-07-21 00:00:00+00:00        21.277778                 21.277778
# 2006-07-21 01:00:00+00:00        17.733333                 17.733333
# 2006-07-21 02:00:00+00:00        17.711111                 17.711111
# 2006-07-21 03:00:00+00:00        17.472222                 17.472222
# 2006-07-21 04:00:00+00:00        16.766667                 16.766667
# ...                                    ...                       ...
# 2006-12-31 18:00:00+00:00        -0.827778                 -4.211111
# 2006-12-31 19:00:00+00:00        -2.011111                 -5.888889
# 2006-12-31 20:00:00+00:00        -1.500000                 -5.327778
# 2006-12-31 21:00:00+00:00        -0.950000                 -4.961111
# 2006-12-31 22:00:00+00:00        -0.672222                 -4.138889
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-07-21 00:00:00+00:00      0.85             2.7370               1018.96
# 2006-07-21 01:00:00+00:00      0.90             2.9946               1020.64
# 2006-07-21 02:00:00+00:00      0.90             6.1502               1020.62
# 2006-07-21 03:00:00+00:00      0.89             1.9159               1020.76
# 2006-07-21 04:00:00+00:00      0.93             3.2200               1020.82
# ...                             ...                ...                   ...
# 2006-12-31 18:00:00+00:00      0.92             9.7405               1035.95
# 2006-12-31 19:00:00+00:00      0.99            10.6904               1035.78
# 2006-12-31 20:00:00+00:00      0.96            10.8997               1034.92
# 2006-12-31 21:00:00+00:00      0.96            12.1394               1035.01
# 2006-12-31 22:00:00+00:00      0.93            10.1430               1034.33
#
# [1750 rows x 5 columns]

# %%
#taking cols for training the model
X_train = X[['Temperature (C)','Humidity','Wind Speed (km/h)','Pressure (millibars)']]
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4248 entries, 2006-01-01 00:00:00+00:00 to 2006-07-20 23:00:00+00:00
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature (C)       4248 non-null   float64
#  1   Humidity              4248 non-null   float64
#  2   Wind Speed (km/h)     4248 non-null   float64
#  3   Pressure (millibars)  4248 non-null   float64
# dtypes: float64(4)
# memory usage: 165.9 KB

# %%
Y_train = X['Apparent Temperature (C)']
Y_train
# Out:
# Formatted Date
# 2006-01-01 00:00:00+00:00    -3.238889
# 2006-01-01 01:00:00+00:00    -3.155556
# 2006-01-01 02:00:00+00:00    -2.194444
# 2006-01-01 03:00:00+00:00    -2.744444
# 2006-01-01 04:00:00+00:00    -3.072222
#                                ...
# 2006-07-20 19:00:00+00:00    25.027778
# 2006-07-20 20:00:00+00:00    23.244444
# 2006-07-20 21:00:00+00:00    22.255556
# 2006-07-20 22:00:00+00:00    19.494444
# 2006-07-20 23:00:00+00:00    19.422222
# Name: Apparent Temperature (C), Length: 4248, dtype: float64

# %%
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#taking cols for testing
X_test = X1[['Temperature (C)','Humidity','Wind Speed (km/h)','Pressure (millibars)']]
X_test
# Out:
#                            Temperature (C)  Humidity  Wind Speed (km/h)  \
# Formatted Date
# 2006-07-21 00:00:00+00:00        21.277778      0.85             2.7370
# 2006-07-21 01:00:00+00:00        17.733333      0.90             2.9946
# 2006-07-21 02:00:00+00:00        17.711111      0.90             6.1502
# 2006-07-21 03:00:00+00:00        17.472222      0.89             1.9159
# 2006-07-21 04:00:00+00:00        16.766667      0.93             3.2200
# ...                                    ...       ...                ...
# 2006-12-31 18:00:00+00:00        -0.827778      0.92             9.7405
# 2006-12-31 19:00:00+00:00        -2.011111      0.99            10.6904
# 2006-12-31 20:00:00+00:00        -1.500000      0.96            10.8997
# 2006-12-31 21:00:00+00:00        -0.950000      0.96            12.1394
# 2006-12-31 22:00:00+00:00        -0.672222      0.93            10.1430
#
#                            Pressure (millibars)
# Formatted Date
# 2006-07-21 00:00:00+00:00               1018.96
# 2006-07-21 01:00:00+00:00               1020.64
# 2006-07-21 02:00:00+00:00               1020.62
# 2006-07-21 03:00:00+00:00               1020.76
# 2006-07-21 04:00:00+00:00               1020.82
# ...                                         ...
# 2006-12-31 18:00:00+00:00               1035.95
# 2006-12-31 19:00:00+00:00               1035.78
# 2006-12-31 20:00:00+00:00               1034.92
# 2006-12-31 21:00:00+00:00               1035.01
# 2006-12-31 22:00:00+00:00               1034.33
#
# [1750 rows x 4 columns]

# %%
Y_test = X1['Apparent Temperature (C)']
Y_test
# Out:
# Formatted Date
# 2006-07-21 00:00:00+00:00    21.277778
# 2006-07-21 01:00:00+00:00    17.733333
# 2006-07-21 02:00:00+00:00    17.711111
# 2006-07-21 03:00:00+00:00    17.472222
# 2006-07-21 04:00:00+00:00    16.766667
#                                ...
# 2006-12-31 18:00:00+00:00    -4.211111
# 2006-12-31 19:00:00+00:00    -5.888889
# 2006-12-31 20:00:00+00:00    -5.327778
# 2006-12-31 21:00:00+00:00    -4.961111
# 2006-12-31 22:00:00+00:00    -4.138889
# Name: Apparent Temperature (C), Length: 1750, dtype: float64

# %%
#predicting the Apparent Temperature
y_pred = regr.predict(X_test)

# %%
regr.score(X_test,Y_test)
# Out:
# 0.9923934744917491

# %% [markdown]
# ### Showing the Actual Apparent Temperature and the predicted Apparent Temperature

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': y_pred})
df
# Out:
#                               Actual  Predicted
# Formatted Date
# 2006-07-21 00:00:00+00:00  21.277778  22.563679
# 2006-07-21 01:00:00+00:00  17.733333  18.561591
# 2006-07-21 02:00:00+00:00  17.711111  18.096287
# 2006-07-21 03:00:00+00:00  17.472222  18.410439
# 2006-07-21 04:00:00+00:00  16.766667  17.459674
# ...                              ...        ...
# 2006-12-31 18:00:00+00:00  -4.211111  -3.313653
# 2006-12-31 19:00:00+00:00  -5.888889  -4.733725
# 2006-12-31 20:00:00+00:00  -5.327778  -4.206968
# 2006-12-31 21:00:00+00:00  -4.961111  -3.758984
# 2006-12-31 22:00:00+00:00  -4.138889  -3.187872
#
# [1750 rows x 2 columns]

# %% [markdown]
# ### Calculating the error in prediction

# %%
from sklearn import metrics
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# Mean Absolute Error:  0.8110788905226683
# Mean Squared Error:  1.0493637098684605
# Root Mean Squared Error:  1.0243845517521535

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor(gamma=0.0453032172664104,
 learning_rate= 0.2155158027999262,
 max_depth= 5,
 n_estimators= 102,
 subsample= 0.9439761626945282)

# %%
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0453032172664104, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2155158027999262,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=102, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# Mean Absolute Error:  0.156794923794284
# Mean Squared Error:  0.0665249362176154
# Root Mean Squared Error:  0.2579242838850491

# %%
from lightgbm import LGBMRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 from lightgbm import LGBMRegressor
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
lgb=LGBMRegressor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 lgb=LGBMRegressor()
#
# NameError: name 'LGBMRegressor' is not defined

# %%
lgb.fit(X_train,Y_train)

# %%
y_pred = lgb.predict(X_test)

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))

# %%
# !pip install catboost

# %%
from catboost import CatBoostRegressor

# %%
cb=CatBoostRegressor()

# %%
cb.fit(X_train,Y_train)

# %%
y_pred = cb.predict(X_test)

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))

# %%
from sklearn.ensemble import StackingRegressor

# %%
estimators = [('regr', regr), ('xgb', XGBRegressor(gamma=0.0453032172664104,
 learning_rate= 0.2155158027999262,
 max_depth= 5,
 n_estimators= 102,
 subsample= 0.9439761626945282)), ('lgb', LGBMRegressor(gamma=0.18727005942368125,
 learning_rate=0.3152142919229748,
 max_depth= 4,
 n_estimators= 107,
 subsample= 0.8394633936788146)),('cb', cb)]

clf = StackingRegressor(estimators=estimators)

# %%
clf.fit(X_train,Y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.meapn_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from scipy.stats import uniform, randint
params = {
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

# %%
xgb=XGBRegressor()

# %%
xgb = RandomizedSearchCV(estimator = xgb, param_distributions = params,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
xgb.fit(idata[:][['Temperature (C)','Humidity','Wind Speed (km/h)','Pressure (millibars)']],idata[:]['Apparent Temperature (C)'])

# %%
xgb.best_params_

# %%
from scipy.stats import uniform, randint
params = {
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

# %%
lgb=LGBMRegressor()

# %%
lgb = RandomizedSearchCV(estimator = lgb, param_distributions = params,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
lgb.fit(idata[:][['Temperature (C)','Humidity','Wind Speed (km/h)','Pressure (millibars)']],idata[:]['Apparent Temperature (C)'])

# %%
lgb.best_params_
